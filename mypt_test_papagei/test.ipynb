# %% [markdown]
# # Quick Start
# ## Import Necessary Packages:

# %%
import sys
sys.path.append("/home/ajhz380/projects/papagei-foundation-model")

# %%
import numpy as np
np.__version__
# Out:
# '1.23.2'

# %%
import sys
print(sys.executable)
# Out:
# /home/ajhz380/miniconda3/envs/papagei_env/bin/python

# %%
from torch_ecg._preprocessors import Normalize
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from torch_ecg._preprocessors import Normalize
#
# File ~/miniconda3/envs/papagei_env/lib/python3.10/site-packages/torch_ecg/__init__.py:4
#       1 """
#       2 """
# ----> 4 from . import _preprocessors, augmenters, components, databases, model_configs, models, preprocessors, utils
#       5 from .version import __version__
#       7 __all__ = [
#       8     "utils",
#       9     "_preprocessors",
#    (...)
#      16     "__version__",
#      17 ]
#
# File ~/miniconda3/envs/papagei_env/lib/python3.10/site-packages/torch_ecg/_preprocessors/__init__.py:32
#       1 """
#       2 torch_ecg._preprocessors
#       3 ========================
#    (...)
#      29
#      30 """
# ---> 32 from .bandpass import BandPass
#      33 from .base import PreProcessor, preprocess_multi_lead_signal, preprocess_single_lead_signal
#      34 from .baseline_remove import BaselineRemove
#
# File ~/miniconda3/envs/papagei_env/lib/python3.10/site-packages/torch_ecg/_preprocessors/bandpass.py:8
#       4 from typing import Any, List, Literal, Optional, Tuple
#       6 import numpy as np
# ----> 8 from .base import PreProcessor, preprocess_multi_lead_signal
#      10 __all__ = [
#      11     "BandPass",
#      12 ]
#      15 class BandPass(PreProcessor):
#
# File ~/miniconda3/envs/papagei_env/lib/python3.10/site-packages/torch_ecg/_preprocessors/base.py:14
#      12 from ..cfg import DEFAULTS
#      13 from ..utils.misc import ReprMixin, add_docstring
# ---> 14 from ..utils.utils_signal import butter_bandpass_filter
#      16 # from scipy.signal import medfilt
#      17 # https://github.com/scipy/scipy/issues/9680
#      20 __all__ = [
#      21     "PreProcessor",
#      22     "preprocess_multi_lead_signal",
#      23     "preprocess_single_lead_signal",
#      24 ]
#
# File ~/miniconda3/envs/papagei_env/lib/python3.10/site-packages/torch_ecg/utils/__init__.py:228
#     203 from .utils_interval import (
#     204     find_extrema,
#     205     generalized_interval_complement,
#    (...)
#     218     validate_interval,
#     219 )
#     220 from .utils_metrics import (
#     221     QRS_score,
#     222     compute_wave_delineation_metrics,
#    (...)
#     226     top_n_accuracy,
#     227 )
# --> 228 from .utils_nn import (
#     229     CkptMixin,
#     230     SizeMixin,
#     231     adjust_cnn_filter_lengths,
#     232     compute_avgpool_output_shape,
#     233     compute_conv_output_shape,
#     234     compute_deconv_output_shape,
#     235     compute_maxpool_output_shape,
#     236     compute_module_size,
#     237     compute_output_shape,
#     238     compute_receptive_field,
#     239     compute_sequential_output_shape,
#     240     default_collate_fn,
#     241     extend_predictions,
#     242 )
#     243 from .utils_signal import (
#     244     butter_bandpass_filter,
#     245     detect_peaks,
#    (...)
#     250     smooth,
#     251 )
#     252 from .utils_signal_t import normalize as normalize_t
#
# File ~/miniconda3/envs/papagei_env/lib/python3.10/site-packages/torch_ecg/utils/utils_nn.py:51
#      46     return [eval(f"np.dtypes.{dtype}") for dtype in dir(np.dtypes) if dtype.endswith("DType")]
#      49 if hasattr(torch.serialization, "add_safe_globals"):
#      50     torch.serialization.add_safe_globals(
# ---> 51         [CFG, EasyDict, np.core.multiarray._reconstruct, np.ndarray, np.dtype] + _get_np_dtypes()
#      52     )
#      55 def extend_predictions(preds: Sequence, classes: List[str], extended_classes: List[str]) -> np.ndarray:
#      56     """Extend the prediction arrays to prediction arrays in larger range of classes
#      57
#      58     Parameters
#    (...)
#      90
#      91     """
#
# File ~/miniconda3/envs/papagei_env/lib/python3.10/site-packages/torch_ecg/utils/utils_nn.py:46, in _get_np_dtypes()
#      45 def _get_np_dtypes():
# ---> 46     return [eval(f"np.dtypes.{dtype}") for dtype in dir(np.dtypes) if dtype.endswith("DType")]
#
# File ~/miniconda3/envs/papagei_env/lib/python3.10/site-packages/numpy/__init__.py:311, in __getattr__(attr)
#     308     from .testing import Tester
#     309     return Tester
# --> 311 raise AttributeError("module {!r} has no attribute "
#     312                      "{!r}".format(__name__, attr))
#
# AttributeError: module 'numpy' has no attribute 'dtypes'

# %%
import numpy as np
import torch
from linearprobing.utils import resample_batch_signal, load_model_without_module_prefix
from preprocessing.ppg import preprocess_one_ppg_signal
from segmentations import waveform_to_segments
from torch_ecg._preprocessors import Normalize
from models.resnet import ResNet1DMoE
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 6
#       4 from preprocessing.ppg import preprocess_one_ppg_signal
#       5 from segmentations import waveform_to_segments
# ----> 6 from torch_ecg._preprocessors import Normalize
#       7 from models.resnet import ResNet1DMoE
#
# File ~/miniconda3/envs/papagei_env/lib/python3.10/site-packages/torch_ecg/__init__.py:4
#       1 """
#       2 """
# ----> 4 from . import _preprocessors, augmenters, components, databases, model_configs, models, preprocessors, utils
#       5 from .version import __version__
#       7 __all__ = [
#       8     "utils",
#       9     "_preprocessors",
#    (...)
#      16     "__version__",
#      17 ]
#
# File ~/miniconda3/envs/papagei_env/lib/python3.10/site-packages/torch_ecg/_preprocessors/__init__.py:32
#       1 """
#       2 torch_ecg._preprocessors
#       3 ========================
#    (...)
#      29
#      30 """
# ---> 32 from .bandpass import BandPass
#      33 from .base import PreProcessor, preprocess_multi_lead_signal, preprocess_single_lead_signal
#      34 from .baseline_remove import BaselineRemove
#
# File ~/miniconda3/envs/papagei_env/lib/python3.10/site-packages/torch_ecg/_preprocessors/bandpass.py:8
#       4 from typing import Any, List, Literal, Optional, Tuple
#       6 import numpy as np
# ----> 8 from .base import PreProcessor, preprocess_multi_lead_signal
#      10 __all__ = [
#      11     "BandPass",
#      12 ]
#      15 class BandPass(PreProcessor):
#
# File ~/miniconda3/envs/papagei_env/lib/python3.10/site-packages/torch_ecg/_preprocessors/base.py:13
#      10 from scipy.ndimage import median_filter
#      12 from ..cfg import DEFAULTS
# ---> 13 from ..utils.misc import ReprMixin, add_docstring
#      14 from ..utils.utils_signal import butter_bandpass_filter
#      16 # from scipy.signal import medfilt
#      17 # https://github.com/scipy/scipy/issues/9680
#
# File ~/miniconda3/envs/papagei_env/lib/python3.10/site-packages/torch_ecg/utils/__init__.py:228
#     203 from .utils_interval import (
#     204     find_extrema,
#     205     generalized_interval_complement,
#    (...)
#     218     validate_interval,
#     219 )
#     220 from .utils_metrics import (
#     221     QRS_score,
#     222     compute_wave_delineation_metrics,
#    (...)
#     226     top_n_accuracy,
#     227 )
# --> 228 from .utils_nn import (
#     229     CkptMixin,
#     230     SizeMixin,
#     231     adjust_cnn_filter_lengths,
#     232     compute_avgpool_output_shape,
#     233     compute_conv_output_shape,
#     234     compute_deconv_output_shape,
#     235     compute_maxpool_output_shape,
#     236     compute_module_size,
#     237     compute_output_shape,
#     238     compute_receptive_field,
#     239     compute_sequential_output_shape,
#     240     default_collate_fn,
#     241     extend_predictions,
#     242 )
#     243 from .utils_signal import (
#     244     butter_bandpass_filter,
#     245     detect_peaks,
#    (...)
#     250     smooth,
#     251 )
#     252 from .utils_signal_t import normalize as normalize_t
#
# File ~/miniconda3/envs/papagei_env/lib/python3.10/site-packages/torch_ecg/utils/utils_nn.py:51
#      46     return [eval(f"np.dtypes.{dtype}") for dtype in dir(np.dtypes) if dtype.endswith("DType")]
#      49 if hasattr(torch.serialization, "add_safe_globals"):
#      50     torch.serialization.add_safe_globals(
# ---> 51         [CFG, EasyDict, np.core.multiarray._reconstruct, np.ndarray, np.dtype] + _get_np_dtypes()
#      52     )
#      55 def extend_predictions(preds: Sequence, classes: List[str], extended_classes: List[str]) -> np.ndarray:
#      56     """Extend the prediction arrays to prediction arrays in larger range of classes
#      57
#      58     Parameters
#    (...)
#      90
#      91     """
#
# File ~/miniconda3/envs/papagei_env/lib/python3.10/site-packages/torch_ecg/utils/utils_nn.py:46, in _get_np_dtypes()
#      45 def _get_np_dtypes():
# ---> 46     return [eval(f"np.dtypes.{dtype}") for dtype in dir(np.dtypes) if dtype.endswith("DType")]
#
# File ~/miniconda3/envs/papagei_env/lib/python3.10/site-packages/numpy/__init__.py:311, in __getattr__(attr)
#     308     from .testing import Tester
#     309     return Tester
# --> 311 raise AttributeError("module {!r} has no attribute "
#     312                      "{!r}".format(__name__, attr))
#
# AttributeError: module 'numpy' has no attribute 'dtypes'
